# %% [markdown]
# # De GW-Grafieken-Raai Tool
#
# Run de cel hieronder om de volledige tool te laden (uitleg, instellingen en interactieve kaart).

# %%
import importlib.util
from pathlib import Path

# Zoek de map met Teken_raai_tool.py (werkt ongeacht vanuit welke map Jupyter start) en laad de module
_here = Path(__file__).parent if "__file__" in globals() else Path.cwd()

from GW_grafieken_raai.GW_grafieken_raai import run_tool

# Bouw de complete layout op: header, uitleg, instellingen, kaart (inline) en exportknop
run_tool(_here)
# Out:
#     <style>
#         /* Primaire knoppen (Genereer kaart, Open kaart, ...) */
#         .jupyter-widgets.widget-button, .jupyter-button.widget-button {
#             background-color: #5CBD7D !important;
#             color: #FFFFFF !important;
#             border: none !important;
#             border-radius: 4px !important;
#             font-weight: 600 !important;
#         }
#         .jupyter-widgets.widget-button:hover:enabled, .jupyter-button.widget-button:hover:enabled {
#             background-color: #BDDECC !important;
#             color: #002E4F !important;
#         }
#         .jupyter-widgets.widget-button:disabled, .jupyter-button.widget-button:disabled {
#             background-color: #EEEEEE !important;
#             color: #B4B4B4 !important;
#         }
#         .jupyter-widgets.widget-button.mod-danger {
#             background-color: #F74646 !important;
#             color: #FFFFFF !important;
#             border: none !important;
#         }
#
#         /* Secundaire knoppen (bladeren, laag toevoegen): wit met Ocean Blue rand */
#         .hsk-btn-secondary, .hsk-btn-secondary.jupyter-widgets.widget-button {
#             background-color: #FFFFFF !important;
#             color: #002E4F !important;
#             border: 1px solid #002E4F !important;
#             border-radius: 4px !important;
#             font-weight: 600 !important;
#         }
#         .hsk-btn-secondary:hover:enabled {
#             background-color: #BDDECC !important;
#         }
#
#         /* Tekstvelden: uniforme achtergrond/rand voor alle pad- en naamvelden */
#         .widget-text input, .widget-text > input,
#         .hsk-input input, .hsk-input.widget-text input {
#             background-color: #F6F6F6 !important;
#             border: 1px solid rgba(0, 46, 79, 0.35) !important;
#             border-radius: 4px !important;
#             color: #002E4F !important;
#         }
#         .hsk-input input:focus {
#             border-color: #002E4F !important;
#             outline: none !important;
#         }
#
#         /* Accordion-koppen */
#         .p-Accordion-title, .lm-AccordionPanel-title, .jupyter-widgets.widget-accordion .widget-box {
#             background-color: #002E4F !important;
#             color: #FFFFFF !important;
#         }
#     </style>
#     <div style="
#         display:flex;
#         align-items:center;
#         justify-content:space-between;
#         gap:16px;
#         background-color:#002E4F;
#         color:#FFFFFF;
#         padding:10px 18px;
#         font-family:Arial, sans-serif;
#         border-radius:4px;margin-bottom:10px;
#     ">
#         <div style="display:flex;align-items:center;gap:14px;">
#             <img src="data:image/svg+xml;base64,..." alt="Haskoning" style="height:32px;width:auto;display:block;">
#             <div>
#                 <div style="font-size:16px;font-weight:700;">GW-Grafieken Raai Tool</div>
#                 <div style="font-size:12px;color:#FFFFFF;opacity:0.85;">Seppe-Schijf grondwatertool — interactieve raai-selectie</div>
#             </div>
#         </div>
#         <div style="font-size:11px;font-style:italic;color:#009EAB;">Enhancing Society Together</div>
#     </div>
#     <div style="font-family:Arial, sans-serif; color:#002E4F; background-color:#FAF2E3;
#                 padding:10px 14px; border-radius:4px; margin-bottom:10px; font-size:13px;">
#         Met deze tool teken je een <b>raai</b> (lijn) op de kaart met een gekozen bufferzone.
#         Alle peilbuizen binnen de buffer worden getoond, samen met de bijbehorende grafieken per modellaag.
#         Stel hieronder de bestandspaden in &mdash; de beschikbare modellagen worden automatisch herkend
#         aan de submappen in de grafieken-map &mdash; en klik daarna op <b>"🗺️ Genereer kaart"</b>
#         om de kaart te maken en op te slaan als HTML. Klik daarna op <b>"🌐 Open kaart"</b> om de kaart
#         in een nieuw browsertabblad te openen.
#         Open de secties hieronder voor gedetailleerde uitleg over de databestanden.
#     </div>
# Accordion(children=(HTML(value='\n    <div style="font-family:Arial, sans-serif; font-size:13px; padding:6px 4…
# <h4 style='color:#002E4F;margin:12px 0 2px;font-family:Arial, sans-serif;'>Instellingen</h4>
# HBox(children=(Text(value='c:\\temo\\review tool Didier\\04_Tool_Concept_v3\\input\\01_bollenkaart_shp\\bollen…
# HBox(children=(Text(value='c:\\temo\\review tool Didier\\04_Tool_Concept_v3\\input\\01_bollenkaart_shp\\bollen…
# HBox(children=(Text(value='c:\\temo\\review tool Didier\\04_Tool_Concept_v3\\input\\01_bollenkaart_shp\\bollen…
# HBox(children=(Text(value='c:\\temo\\review tool Didier\\04_Tool_Concept_v3\\input\\02_grafieken_png', descrip…
# HBox(children=(Text(value='c:\\temo\\review tool Didier\\04_Tool_Concept_v3\\output\\Teken_raaitool.html', des…
# HTML(value='\n    <hr style="border-color:#F6F6F6;">\n    <b style="font-size:13px;color:#002E4F;">Achtergrond…
# VBox(children=(HBox(children=(Text(value='c:\\temo\\review tool Didier\\04_Tool_Concept_v3\\input\\00_achtergr…
# Button(description='➕ Voeg achtergrondlaag toe', layout=Layout(margin='6px 0 0 0', width='240px'), style=Butto…
# HBox(children=(Button(description='🗺️ Genereer kaart', layout=Layout(margin='12px 8px 0 0', width='200px'), st…
# Output()
